# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Retail Data.csv')

# %%
df.head()
# Out:
#   Order No  Order Date           Customer Name  \
# 0   4293-1  02-09-2014        Vivek Sundaresam
# 1   5001-1  24-10-2015          Shahid Hopkins
# 2   5004-1  13-03-2014           Dennis Pardue
# 3   5009-1  18-02-2013              Sean Wendt
# 4   5010-1  13-09-2014  Christina Vanderzanden
#
#                           Address       City State   Customer Type  \
# 0  152 Bunnerong Road,Eastgardens     Sydney   NSW  Small Business
# 1   438 Victoria Avenue,Chatswood     Sydney   NSW       Corporate
# 2        412 Brunswick St,Fitzroy  Melbourne   VIC        Consumer
# 3        145 Ramsay St,Haberfield     Sydney   NSW  Small Business
# 4          188 Pitt Street,Sydney     Sydney   NSW  Small Business
#
#   Account Manager Order Priority  \
# 0    Tina Carlton       Critical
# 1    Natasha Song         Medium
# 2    Connor Betts  Not Specified
# 3     Phoebe Gour       Critical
# 4    Tina Carlton  Not Specified
#
# ...

# %%
df.columns
# Out:
# Index(['Order No', 'Order Date', 'Customer Name', 'Address', 'City', 'State',
#        'Customer Type', 'Account Manager', 'Order Priority', 'Product Name',
#        'Product Category', 'Product Container', 'Ship Mode', 'Ship Date',
#        'Cost Price', 'Retail Price', 'Profit Margin', 'Order Quantity',
#        'Sub Total', 'Discount %', 'Discount $', 'Order Total', 'Shipping Cost',
#        'Total'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['Order_No', 'Order_Date', 'Customer_Name', 'Address', 'City', 'State',
#        'Customer_Type', 'Account_Manager', 'Order_Priority', 'Product_Name',
#        'Product_Category', 'Product_Container', 'Ship_Mode', 'Ship_Date',
#        'Cost_Price', 'Retail_Price', 'Profit_Margin', 'Order_Quantity',
#        'Sub_Total', 'Discount_%', 'Discount_$', 'Order_Total', 'Shipping_Cost',
#        'Total'],
#       dtype='object')

# %%
dtypes = df.dtypes.astype(str)
print(dtypes)
# Out:
# Order_No              object
# Order_Date            object
# Customer_Name         object
# Address               object
# City                  object
# State                 object
# Customer_Type         object
# Account_Manager       object
# Order_Priority        object
# Product_Name          object
# Product_Category      object
# Product_Container     object
# Ship_Mode             object
# Ship_Date             object
# Cost_Price            object
# Retail_Price          object
# Profit_Margin         object
# Order_Quantity       float64
# Sub_Total             object
# Discount_%            object
# Discount_$            object
# Order_Total           object
# Shipping_Cost         object
# Total                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_No             0
# Order_Date           0
# Customer_Name        0
# Address              1
# City                 0
# State                0
# Customer_Type        0
# Account_Manager      0
# Order_Priority       0
# Product_Name         0
# Product_Category     0
# Product_Container    0
# Ship_Mode            0
# Ship_Date            0
# Cost_Price           0
# Retail_Price         0
# Profit_Margin        0
# Order_Quantity       1
# Sub_Total            0
# Discount_%           0
# Discount_$           0
# Order_Total          0
# Shipping_Cost        0
# Total                0
# dtype: int64

# %%
df.shape
# Out:
# (5000, 24)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], dayfirst=True, errors='coerce')
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'], dayfirst=True, errors='coerce')

# %%
df[['Order_Date', 'Ship_Date']].head()
# Out:
#   Order_Date  Ship_Date
# 0 2014-09-02 2014-09-04
# 1 2015-10-24 2015-10-26
# 2 2014-03-13 2014-03-13
# 3 2013-02-18 2013-02-20
# 4 2014-09-13 2014-09-17

# %%
df.columns
# Out:
# Index(['Order_No', 'Order_Date', 'Customer_Name', 'Address', 'City', 'State',
#        'Customer_Type', 'Account_Manager', 'Order_Priority', 'Product_Name',
#        'Product_Category', 'Product_Container', 'Ship_Mode', 'Ship_Date',
#        'Cost_Price', 'Retail_Price', 'Profit_Margin', 'Order_Quantity',
#        'Sub_Total', 'Discount_%', 'Discount_$', 'Order_Total', 'Shipping_Cost',
#        'Total'],
#       dtype='object')

# %%
# Count number of orders per city
city_orders = df['City'].value_counts().head(10)

# Display top 10 cities
print(city_orders)
# Out:
# City
# Sydney       3584
# Melbourne    1416
# Name: count, dtype: int64

# %%
city_orders = (
    df.groupby('City')['Order_No']
      .count()
      .sort_values(ascending=False)
      .reset_index(name='Total_Orders')
)

print(city_orders.head(10))
# Out:
#         City  Total_Orders
# 0     Sydney          3584
# 1  Melbourne          1416

# %%
df.head(10)
# Out:
#   Order_No Order_Date           Customer_Name  \
# 0   4293-1 2014-09-02        Vivek Sundaresam
# 1   5001-1 2015-10-24          Shahid Hopkins
# 2   5004-1 2014-03-13           Dennis Pardue
# 3   5009-1 2013-02-18              Sean Wendt
# 4   5010-1 2014-09-13  Christina Vanderzanden
# 5   5011-1 2013-11-24          Patrick OBrill
# 6   5012-1 2014-09-07            Eugene Moren
# 7   5012-1 2015-01-28       Phillip Flathmann
# 8   5014-1 2014-06-08                John Lee
# 9   5015-1 2014-10-02         Ritsa Hightower
#
#                                              Address       City State  \
# 0                     152 Bunnerong Road,Eastgardens     Sydney   NSW
# 1                      438 Victoria Avenue,Chatswood     Sydney   NSW
# 2                           412 Brunswick St,Fitzroy  Melbourne   VIC
# 3                           145 Ramsay St,Haberfield     Sydney   NSW
# 4                             188 Pitt Street,Sydney     Sydney   NSW
# ...

# %%
df.columns
# Out:
# Index(['Order_No', 'Order_Date', 'Customer_Name', 'Address', 'City', 'State',
#        'Customer_Type', 'Account_Manager', 'Order_Priority', 'Product_Name',
#        'Product_Category', 'Product_Container', 'Ship_Mode', 'Ship_Date',
#        'Cost_Price', 'Retail_Price', 'Profit_Margin', 'Order_Quantity',
#        'Sub_Total', 'Discount_%', 'Discount_$', 'Order_Total', 'Shipping_Cost',
#        'Total'],
#       dtype='object')

# %%
df['Customer_Type'].unique()
# Out:
# array(['Small Business', 'Corporate', 'Consumer', 'Home Office'],
#       dtype=object)

# %%
if 'Customer_Type':
    print("Customer Types:", df['Customer_Type'].dropna().unique().tolist())
# Out:
# Customer Types: ['Small Business', 'Corporate', 'Consumer', 'Home Office']

# %%
if 'Order_Priority':
        print("Order priorities:", df['Order_Priority'].dropna().unique().tolist())
# Out:
# Order priorities: ['Critical', 'Medium', 'Not Specified', 'Low', 'High']

# %%
df.head(10)
# Out:
#   Order_No Order_Date           Customer_Name  \
# 0   4293-1 2014-09-02        Vivek Sundaresam
# 1   5001-1 2015-10-24          Shahid Hopkins
# 2   5004-1 2014-03-13           Dennis Pardue
# 3   5009-1 2013-02-18              Sean Wendt
# 4   5010-1 2014-09-13  Christina Vanderzanden
# 5   5011-1 2013-11-24          Patrick OBrill
# 6   5012-1 2014-09-07            Eugene Moren
# 7   5012-1 2015-01-28       Phillip Flathmann
# 8   5014-1 2014-06-08                John Lee
# 9   5015-1 2014-10-02         Ritsa Hightower
#
#                                              Address       City State  \
# 0                     152 Bunnerong Road,Eastgardens     Sydney   NSW
# 1                      438 Victoria Avenue,Chatswood     Sydney   NSW
# 2                           412 Brunswick St,Fitzroy  Melbourne   VIC
# 3                           145 Ramsay St,Haberfield     Sydney   NSW
# 4                             188 Pitt Street,Sydney     Sydney   NSW
# ...

# %%
df.dtypes
# Out:
# Order_No                     object
# Order_Date           datetime64[ns]
# Customer_Name                object
# Address                      object
# City                         object
# State                        object
# Customer_Type                object
# Account_Manager              object
# Order_Priority               object
# Product_Name                 object
# Product_Category             object
# Product_Container            object
# Ship_Mode                    object
# Ship_Date            datetime64[ns]
# Cost_Price                   object
# Retail_Price                 object
# Profit_Margin                object
# Order_Quantity              float64
# Sub_Total                    object
# Discount_%                   object
# Discount_$                   object
# Order_Total                  object
# Shipping_Cost                object
# Total                        object
# dtype: object

# %%
# df[["Cost_Price","Retail_Price","Profit_Margin","Sub_Total","Discount_%","Order_Total"]].astype(float)

cols_to_convert = ["Cost_Price", "Retail_Price", "Profit_Margin","Total",
                   "Sub_Total", "Discount_%", "Order_Total","Shipping_Cost"]

df[cols_to_convert] = df[cols_to_convert].replace('[|$,%,]','',regex =True)

df[cols_to_convert] = df[cols_to_convert].astype(float)

# %%
df.dtypes
# Out:
# Order_No                     object
# Order_Date           datetime64[ns]
# Customer_Name                object
# Address                      object
# City                         object
# State                        object
# Customer_Type                object
# Account_Manager              object
# Order_Priority               object
# Product_Name                 object
# Product_Category             object
# Product_Container            object
# Ship_Mode                    object
# Ship_Date            datetime64[ns]
# Cost_Price                  float64
# Retail_Price                float64
# Profit_Margin               float64
# Order_Quantity              float64
# Sub_Total                   float64
# Discount_%                  float64
# Discount_$                   object
# Order_Total                 float64
# Shipping_Cost               float64
# Total                       float64
# dtype: object

# %%
df.head()
# Out:
#   Order_No Order_Date           Customer_Name                         Address  \
# 0   4293-1 2014-09-02        Vivek Sundaresam  152 Bunnerong Road,Eastgardens
# 1   5001-1 2015-10-24          Shahid Hopkins   438 Victoria Avenue,Chatswood
# 2   5004-1 2014-03-13           Dennis Pardue        412 Brunswick St,Fitzroy
# 3   5009-1 2013-02-18              Sean Wendt        145 Ramsay St,Haberfield
# 4   5010-1 2014-09-13  Christina Vanderzanden          188 Pitt Street,Sydney
#
#         City State   Customer_Type Account_Manager Order_Priority  \
# 0     Sydney   NSW  Small Business    Tina Carlton       Critical
# 1     Sydney   NSW       Corporate    Natasha Song         Medium
# 2  Melbourne   VIC        Consumer    Connor Betts  Not Specified
# 3     Sydney   NSW  Small Business     Phoebe Gour       Critical
# 4     Sydney   NSW  Small Business    Tina Carlton  Not Specified
#
#                                      Product_Name  ... Cost_Price  \
# ...

# %%
df.columns
# Out:
# Index(['Order_No', 'Order_Date', 'Customer_Name', 'Address', 'City', 'State',
#        'Customer_Type', 'Account_Manager', 'Order_Priority', 'Product_Name',
#        'Product_Category', 'Product_Container', 'Ship_Mode', 'Ship_Date',
#        'Cost_Price', 'Retail_Price', 'Profit_Margin', 'Order_Quantity',
#        'Sub_Total', 'Discount_%', 'Discount_$', 'Order_Total', 'Shipping_Cost',
#        'Total'],
#       dtype='object')

# %%
revenue_manager =df.groupby('Account_Manager')['Total'].sum().sort_values(ascending=False)

print(revenue_manager.head())
# Out:
# Account_Manager
# Connor Betts          671173.17
# Tina Carlton          453891.62
# Yvette Biti           379687.12
# Nicholas Fernandes    305927.88
# Mihael Khan           281948.64
# Name: Total, dtype: float64

# %%
df.groupby('Order_No')['Total'].sum().sort_values(ascending=False).head()
# Out:
# Order_No
# 5400-1    98729.73
# 6088-1    83603.54
# 6384-1    78038.40
# 5498-1    76834.60
# 5930-1    67230.36
# Name: Total, dtype: float64

# %%
df.groupby('Customer_Type')['Total'].sum().sort_values(ascending=False).head()
# Out:
# Customer_Type
# Corporate         1373796.44
# Home Office        851621.96
# Small Business     830886.35
# Consumer           675231.65
# Name: Total, dtype: float64

# %%
df.groupby('Order_Priority')['Order_Priority'].count().sort_values().head()
# Out:
# Order_Priority
# Low               861
# Critical          885
# Medium           1038
# Not Specified    1092
# High             1124
# Name: Order_Priority, dtype: int64

# %%
df.groupby('Profit_Margin')['Product_Category'].count().sort_values().head()
# Out:
# Profit_Margin
# 0.36      1
# 226.33    1
# 40.97     1
# 15.27     1
# 8.79      1
# Name: Product_Category, dtype: int64

# %%
df.groupby('Ship_Mode')

# %%
df.shape
# Out:
# (5000, 24)

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', 1000)   # prevents wrapping


# df.head

# %%
df['Shipping_Days'] = (df['Ship_Date'] - df['Order_Date']).dt.days

print(df[['Order_No', 'Order_Date', 'Ship_Date', 'Shipping_Days']].head())
# Out:
#   Order_No Order_Date  Ship_Date  Shipping_Days
# 0   4293-1 2014-09-02 2014-09-04              2
# 1   5001-1 2015-10-24 2015-10-26              2
# 2   5004-1 2014-03-13 2014-03-13              0
# 3   5009-1 2013-02-18 2013-02-20              2
# 4   5010-1 2014-09-13 2014-09-17              4

# %%
print(df[['Order_No', 'Order_Date', 'Ship_Date', 'Shipping_Days','Profit_Margin']].head().max())
# Out:
# Order_No                      5010-1
# Order_Date       2015-10-24 00:00:00
# Ship_Date        2015-10-26 00:00:00
# Shipping_Days                      4
# Profit_Margin                 144.47
# dtype: object

# %%
data = df['Shipping_Days'].corr(df['Profit_Margin'])

# %%
round(data,2)
# Out:
# -0.02

# %%
df.groupby('City')['Total'].sum()
# Out:
# City
# Melbourne    1052756.07
# Sydney       2678780.33
# Name: Total, dtype: float64

# %%
df.groupby('Account_Manager')['Total'].sum().sort_values(ascending=False).reset_index().head(1)
# Out:
#   Account_Manager      Total
# 0    Connor Betts  671173.17

# %%
df.head()
# Out:
#   Order_No Order_Date           Customer_Name                         Address  \
# 0   4293-1 2014-09-02        Vivek Sundaresam  152 Bunnerong Road,Eastgardens
# 1   5001-1 2015-10-24          Shahid Hopkins   438 Victoria Avenue,Chatswood
# 2   5004-1 2014-03-13           Dennis Pardue        412 Brunswick St,Fitzroy
# 3   5009-1 2013-02-18              Sean Wendt        145 Ramsay St,Haberfield
# 4   5010-1 2014-09-13  Christina Vanderzanden          188 Pitt Street,Sydney
#
#         City State   Customer_Type Account_Manager Order_Priority  \
# 0     Sydney   NSW  Small Business    Tina Carlton       Critical
# 1     Sydney   NSW       Corporate    Natasha Song         Medium
# 2  Melbourne   VIC        Consumer    Connor Betts  Not Specified
# 3     Sydney   NSW  Small Business     Phoebe Gour       Critical
# 4     Sydney   NSW  Small Business    Tina Carlton  Not Specified
#
#                                      Product_Name  ... Retail_Price  \
# ...

# %%
df.groupby('Ship_Mode')['Shipping_Cost'].mean().sort_values(ascending=False).reset_index()
# Out:
#         Ship_Mode  Shipping_Cost
# 0     Regular Air       5.503553
# 1  Delivery Truck       5.270085
# 2     Express Air       5.247311

# %%
data = df['Discount_%'].corr(df['Profit_Margin'])
print(round(data,2))
# Out:
# -0.03

# %%
df.groupby('State')['Order_No'].count().sort_values(ascending=False).reset_index()
# Out:
#   State  Order_No
# 0   NSW      3584
# 1   VIC      1416

# %%
round(df['Discount_%'].mean(),2)
# Out:
# 5.03

# %%
df.groupby('Order_No')['Order_Total'].mean().sort_values(ascending=False).reset_index().head()
# Out:
#   Order_No   Order_Total
# 0   6017-1  25667.570000
# 1   5930-1  22382.296667
# 2   5757-1  18535.890000
# 3   6088-1  16658.270000
# 4   5498-1  15335.464000

# %%
round(df['Total'].mean(),2)
# Out:
# 746.31

# %%
round(df.groupby('Product_Container')['Profit_Margin'].mean().sort_values(ascending=False).reset_index(),2)
# Out:
#   Product_Container  Profit_Margin
# 0         Small Box          19.67
# 1        Small Pack          16.84
# 2        Jumbo Drum          16.48
# 3          Wrap Bag          16.41
# 4        Medium Box          15.64
# 5         Large Box          11.64
